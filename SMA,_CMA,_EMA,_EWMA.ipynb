# %% [markdown]
# <a href="https://colab.research.google.com/github/manasik29/Time_Series_Forecasting/blob/main/SMA%2C_CMA%2C_EMA%2C_EWMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas
# !pip install --upgrade pandas-datareader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 109 kB 13.6 MB/s
# ...
#   Attempting uninstall: pandas-datareader
#     Found existing installation: pandas-datareader 0.9.0
#     Uninstalling pandas-datareader-0.9.0:
#       Successfully uninstalled pandas-datareader-0.9.0
# ...

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
df_tesla = pdr.get_data_yahoo('TSLA')
df_tesla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-08-18  70.800003  69.160004  70.582001  69.491997  27041000.0  69.491997
# 2017-08-21  69.164001  66.370003  69.164001  67.571999  32477000.0  67.571999
# 2017-08-22  68.447998  67.473999  68.225998  68.269997  21610000.0  68.269997
# 2017-08-23  70.697998  67.660004  67.797997  70.554001  24772500.0  70.554001
# 2017-08-24  71.332001  69.947998  70.503998  70.585999  22923500.0  70.585999

# %% [markdown]
# ## **Simple Moving Average**

# %%
df_tesla['Open'].plot(figsize=(15,6))

# %%
df_tesla['Open: 10 days rolling'] = df_tesla['Open'].rolling(window=10, min_periods=1).mean()
df_tesla.head(20)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2017-08-18  70.800003  69.160004  70.582001  69.491997  27041000.0  69.491997
# 2017-08-21  69.164001  66.370003  69.164001  67.571999  32477000.0  67.571999
# 2017-08-22  68.447998  67.473999  68.225998  68.269997  21610000.0  68.269997
# 2017-08-23  70.697998  67.660004  67.797997  70.554001  24772500.0  70.554001
# 2017-08-24  71.332001  69.947998  70.503998  70.585999  22923500.0  70.585999
# 2017-08-25  71.138000  69.459999  70.848000  69.610001  17420000.0  69.610001
# 2017-08-28  69.470001  67.944000  69.456001  69.132004  18820000.0  69.132004
# 2017-08-29  69.809998  67.750000  67.896004  69.472000  20368500.0  69.472000
# 2017-08-30  70.694000  69.400002  69.933998  70.636002  17064500.0  70.636002
# 2017-08-31  71.688004  70.564003  70.709999  71.180000  20364000.0  71.180000
# 2017-09-01  71.517998  70.737999  71.223999  71.080002  15247500.0  71.080002
# ...

# %%
df_tesla[['Open', 'Open: 10 days rolling']].plot(xlim = ['2021-01-01', '2022-01-01'], figsize=(15,6))

# %% [markdown]
# - We get a smoother curve

# %%
df_tesla['Open: 30 days rolling'] = df_tesla['Open'].rolling(window=30, min_periods=1).mean()
df_tesla['Open: 50 days rolling'] = df_tesla['Open'].rolling(window=50, min_periods=1).mean()

# %%
df_tesla[['Open', 'Open: 10 days rolling', 'Open: 30 days rolling', 'Open: 50 days rolling']].plot(xlim = ['2021-01-01', '2022-01-01'], figsize=(15,6))

# %%
## Similar importance to all te data points
## In timeseries data we need to give more weight to recent data

# %% [markdown]
# ## **Cummulative Moving Average**

# %%
df_tesla['Open'].expanding().mean().plot(figsize=(10,6))

# %% [markdown]
# ## **EMA & EWMA**

# %%
## EMA

df_tesla['EMA_0.1'] = df_tesla['Open'].ewm(alpha=0.1, adjust=False).mean()
df_tesla[['Open', 'EMA_0.1']].plot(figsize=(15,6))

# %%
##EWMA

df_tesla['EWMA_5days'] = df_tesla['Open'].ewm(span=5).mean()
df_tesla[['Open', 'EMA_0.1', 'EWMA_5days']].plot(figsize=(15,6))
